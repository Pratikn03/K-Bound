# %% [markdown]
# # K-Bound — Reproduction Notebook
# ### *When Is Label-Free Adaptation Knowable?*  (KGA: Knowability-Guided Adaptation)
#
# This is the **reviewer-facing reproduction** of the K-Bound paper. It (1) runs the core
# adapt/freeze/abstain trichotomy **live** on the 123-task suite, (2) loads every experiment's
# **real** result artifact, and (3) renders the figures inline. Nothing is fabricated; every
# number is produced by code in this repo.
#
# **Decision rule.** Evidence `Z = φ(·)` (label-free) → certificate `Δ̂(Z) ± ε` →
# **ADAPT** if `Δ̂−ε>0`, **FREEZE** if `Δ̂+ε<0`, else **ABSTAIN**.
#
# **One-command full reproduction:** `PYTHON=.venv/bin/python bash scripts/rebuild_kbound.sh`
#   ·  Paper: `docs/research/kbound/K-Bound_paper.pdf`  ·  Dashboard: `docs/research/kbound/kbound_dashboard.html`
#
# > Legacy `notebooks/01..99_*.ipynb` are ELARA-era EDA (the superseded foundation); this notebook is the current K-Bound work.

# %% [markdown]
# ## 0 · Setup (locates the repo root automatically)

# %%
import os, json, glob, numpy as np
from scipy.stats import ks_2samp, rankdata
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import roc_auc_score

# walk up from the notebook's location until we find the repo marker
REPO=os.path.abspath(os.getcwd())
while REPO!='/' and not os.path.exists(os.path.join(REPO,'scripts','rebuild_kbound.sh')):
    REPO=os.path.dirname(REPO)
ARCH=os.path.join(REPO,'experiments','elara_u','score_archive')
RES =os.path.join(REPO,'experiments','kbound','results')
FIG =os.path.join(REPO,'docs','research','kbound','figures')
print('repo root :', REPO)
print('score tasks:', len(glob.glob(ARCH+'/*.npz')), ' | result files:', len(glob.glob(RES+'/*.json')))
# Out:
# repo root : /sessions/optimistic-amazing-ritchie/mnt/uav/AutoML_Flagship_V8
# score tasks: 123  | result files: 14

# %% [markdown]
# ## 1 · Live reproduction — the KGA trichotomy on the 123-task suite
# Frozen `f0` = best-validation detector; candidate `f_a` = rank-normalised logistic stack.
# True benefit `B = AUROC(f_a) − AUROC(f0)` (oracle; labels used only for scoring). The decision
# uses **label-free** evidence `Z` via a leave-one-out estimator + conformal radius `ε`.

# %%
def rank_norm(S):
    R=np.empty_like(S,dtype=float)
    for j in range(S.shape[1]): R[:,j]=(rankdata(S[:,j])-1)/(len(S)-1)
    return R
def auc(y,s): return roc_auc_score(y,s) if len(np.unique(y))>1 else np.nan
rows=[]
for f in sorted(glob.glob(ARCH+'/*.npz')):
    d=np.load(f,allow_pickle=True); Sval,yval,Stest,ytest,va=d['Sval'],d['yval'],d['Stest'],d['ytest'],d['val_auc']
    if len(np.unique(ytest))<2: continue
    j0=int(np.argmax(va)); a0=auc(ytest,Stest[:,j0])
    clf=LogisticRegression(max_iter=1000).fit(rank_norm(Sval),yval); aa=auc(ytest,clf.predict_proba(rank_norm(Stest))[:,1])
    ks=[ks_2samp(Sval[:,k],Stest[:,k]).statistic for k in range(Sval.shape[1])]
    Rt=rank_norm(Stest); C=np.corrcoef(Rt.T); iu=np.triu_indices_from(C,k=1); vs=np.sort(va)[::-1]
    Z=[float(vs[0]),float(vs[0]-vs[1]),float(np.mean(va)),float(np.mean(ks)),float(np.max(ks)),float(1-np.nanmean(C[iu])),float(np.std(va)),float(np.mean(yval)),float(np.log(len(ytest)))]
    rows.append((Z,float(aa-a0)))
X=np.array([r[0] for r in rows]); B=np.array([r[1] for r in rows]); N=len(B)
Bhat=np.zeros(N)
for i in range(N):
    tr=np.arange(N)!=i
    m=GradientBoostingRegressor(n_estimators=200,max_depth=2,learning_rate=0.05,subsample=0.8,random_state=0).fit(X[tr],B[tr])
    Bhat[i]=m.predict(X[i:i+1])[0]
eps=float(np.quantile(np.abs(Bhat-B),0.9)); dec=np.where(Bhat-eps>0,'ADAPT',np.where(Bhat+eps<0,'FREEZE','ABSTAIN')); ad=dec=='ADAPT'
print(f'N={N}  conformal eps={eps:.3f}')
print('decisions:', {k:int((dec==k).sum()) for k in ["ADAPT","FREEZE","ABSTAIN"]})
print(f'adapt precision (B>0 | ADAPT) = {np.mean(B[ad]>0):.3f}')
print(f'abstain mean|B| = {np.mean(np.abs(B[dec=="ABSTAIN"])):.3f}   vs   acted mean|B| = {np.mean(np.abs(B[dec!="ABSTAIN"])):.3f}')
print('--> KGA abstains precisely where the true benefit is near zero.')
# Out:
# N=123  conformal eps=0.081
# decisions: {'ADAPT': 9, 'FREEZE': 0, 'ABSTAIN': 114}
# adapt precision (B>0 | ADAPT) = 0.778
# abstain mean|B| = 0.031   vs   acted mean|B| = 0.160
# --> KGA abstains precisely where the true benefit is near zero.

# %% [markdown]
# ## 2 · All experiment results (loaded from real artifacts)

# %%
def show(name, path, keys):
    p=os.path.join(RES,path)
    if not os.path.exists(p): print('[missing]',name); return
    s=json.load(open(p)); s=s.get('summary',s)
    print('###',name)
    for k in keys:
        if isinstance(s,dict) and k in s: print('   ',k,'=',s[k])
    print()
show('Mixed regime (decisive, AUROC)','mixed_regime_results.json',['mean_auc_policies','regret_vs_oracle','safety'])
show('8-seed rigor + paired t-tests','rigor_multiseed.json',['mean_std','paired_ttest_KBound_vs_always_freeze','paired_ttest_KBound_vs_always_adapt'])
show('Harmful fusion regime (AUROC)','kbound_harmful_results.json',['mean_auc','regret_vs_oracle'])
show('CIFAR-10-C suite (65 cells, acc)','cifar10c_suite_results.json',['avg_accuracy','false_adapt_rate'])
show('CIFAR-10-C + Tent (decisive)','decisive_tta_results.json',['alpha'])
show('Online continual-Tent (harsh)','cifar_tent_online_results.json',['mean_stream_accuracy','regret_vs_oracle','kga_decision_counts'])
show('Regression covariate-shift','regression_covariate.json',['decision_counts','mean_MSE'])
show('Non-identifiability witness','witness_clean.json',['abstain_rate','all_Z_features_p>0.05','world0_mean_B','world1_mean_B'])
# Out:
# ### Mixed regime (decisive, AUROC)
#     mean_auc_policies = {'always_adapt': 0.6971114217409946, 'always_freeze': 0.5862362368571814, 'K_Bound': 0.6898522630259771, 'oracle': 0.7189128955491799}
#     regret_vs_oracle = {'always_adapt': 0.021801473808185413, 'always_freeze': 0.13267665869199857, 'K_Bound': 0.029060632523202765}
#     safety = {'adapt_precision_B>0': 0.9347826086956522, 'false_adapt_rate_B<0': 0.06521739130434782}
#
# ### 8-seed rigor + paired t-tests
#     mean_std = {'always_adapt': [0.6969783881179049, 8.399016284971985e-05], 'always_freeze': [0.5841853559610777, 0.0014670002792189914], 'K_Bound': [0.6859821592117441, 0.003336273617313085], 'oracle': [0.7180348491228252, 0.0006395177786479187], 'false_adapt': [0.0642338226689941, 0.010144348824235894], 'adapt_precision': [0.9357661773310059, 0.010144348824235917], 'coverage': [0.37262872628726285, 0.01745812835599611]}
#     paired_ttest_KBound_vs_always_freeze = {'t': 62.235774407328385, 'p': 7.261976392007134e-11}
#     paired_ttest_KBound_vs_always_adapt = {'t': -8.75989045559896, 'p': 5.0842555812787246e-05}
#
# ### Harmful fusion regime (AUROC)
#     mean_auc = {'always_adapt(elara_fuse)': 0.7284284552845529, 'always_freeze(auto_select)': 0.7480577235772359, 'K-Bound_trichotomy': 0.7479455284552846, 'oracle': 0.7498634146341464}
#     regret_vs_oracle = {'always_adapt': 0.0214349593495935, 'always_freeze': 0.0018056910569105692, 'K-Bound': 0.001917886178861789}
#
# ### CIFAR-10-C suite (65 cells, acc)
#     avg_accuracy = {'frozen': 0.4121153843804048, 'tent': 0.6258846148275412, 'eata': 0.6257499996859294, 'sar': 0.6268461520282121, 'kga': 0.6257499998578658, 'oracle': 0.6289038488498101}
#     false_adapt_rate = {'frozen': 0.0, 'tent': 0.015384615384615385, 'eata': 0.015384615384615385, 'sar': 0.015384615384615385, 'kga': 0.015384615384615385}
#
# ### CIFAR-10-C + Tent (decisive)
#     alpha = 0.1
#
# ### Online continual-Tent (harsh)
#     mean_stream_accuracy = {'freeze': [0.4398148148148148, 0.008880792391911349], 'adapt': [0.3393132716049383, 0.025083466087578426], 'kga': [0.42573302469135804, 0.009138918661168735], 'oracle': [0.6304976851851852, 0.006992503456941294]}
#     regret_vs_oracle = {'freeze': 0.1906828703703704, 'adapt': 0.29118441358024694, 'kga': 0.2047646604938272}
#     kga_decision_counts = {'ADAPT': 40, 'FREEZE': 12, 'ABSTAIN': 2}
#
# ### Regression covariate-shift
#     decision_counts = {'ADAPT': 0, 'FREEZE': 11, 'ABSTAIN': 61}
#     mean_MSE = {'always_adapt(IW)': 0.33760123811511755, 'always_freeze': 0.25125518532302443, 'K_Bound': 0.25125518532302443, 'oracle': 0.2511881678882004}
#
# ### Non-identifiability witness
#     abstain_rate = 1.0
#     all_Z_features_p>0.05 = True
#     world0_mean_B = -1.0
#     world1_mean_B = 1.0

# %% [markdown]
# ## 3 · Figures (architecture + key results)

# %%
from IPython.display import Image, display
for fn in ['fig_architecture.png','fig_mixed_policies.png','fig_cifar10c_collapse.png','fig_cifar_tent_online.png','fig_witness_clean.png']:
    p=os.path.join(FIG,fn)
    if os.path.exists(p): print(fn); display(Image(filename=p,width=720))
# Out:
# fig_architecture.png
# fig_mixed_policies.png
# fig_cifar10c_collapse.png
# fig_cifar_tent_online.png
# fig_witness_clean.png

# %% [markdown]
# ## 4 · Theorem status & reproduce
# 5/5 core theorems proved (Thm 3 conditional, Thm 5 binary→multiclass), e-value anytime certificate, **33/33 theorem tests pass**;
# ELARA T1–T9 + GDR underpin the fusion instantiation. Full map: `docs/research/kbound/THEOREM_CODE_STATUS.md`.
#
# ```bash
# PYTHON=.venv/bin/python bash scripts/rebuild_kbound.sh            # CPU experiments + paper
# KBOUND_GPU=1 PYTHON=.venv/bin/python bash scripts/rebuild_kbound.sh   # + GPU TTA
# ```
#
# **Honest scope:** per-corruption CIFAR-10-C is helpful-dominated (always-adapt strong; KGA matches it safely);
# KGA's distinctive value is safety + cross-regime robustness; full 1000-class ImageNet-C is pending (host unreachable).
